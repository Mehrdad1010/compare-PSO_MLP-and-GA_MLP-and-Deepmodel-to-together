# %% [markdown]
# <h5 style="color:rgba(0, 0, 178, 0.6);">This code hidden warrnings</h5>

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <h5 style="color:rgba(0, 0, 178, 0.6);">Install librarys that we need</h5>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use("bmh")
from tensorflow import keras
from sklearn.cluster import KMeans
import random
import tensorflow as tf
from sklearn.metrics import r2_score
from sklearn.preprocessing import StandardScaler
tf.__version__
# Out:
# WARNING:tensorflow:From C:\Program Files\Python310\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# '2.15.0'

# %% [markdown]
# <h5 style="color:rgba(0, 0, 178, 0.6);">Read the data from data set</h5>

# %%
df = pd.read_csv("../../DATA/Data_increase.csv").drop(["Unnamed: 0","Unnamed: 0.1"], axis=1)
df["LLD-LLS"] = df.log_LLD - df.log_LLS
df["GR-GKUT"] = df.GR - df.GKUT
df
# Out:
#             DEPT       GR       GKUT      NPHI      PE    RHOB      DRHO  \
# 0      2705.2524  19.0270  18.728100  0.051300  5.2064  2.6527  0.019800
# 1      2705.4048  15.8497  16.507000  0.046800  5.2632  2.6564  0.022900
# 2      2705.5572  13.3455  14.392100  0.041100  5.2742  2.6546  0.021800
# 3      2705.7096  12.2315  13.696900  0.036900  5.2543  2.6488  0.020200
# 4      2705.8620  13.0494  13.258900  0.032200  5.1625  2.6475  0.014500
# ...          ...      ...        ...       ...     ...     ...       ...
# 17456  2979.2676  24.4099  33.716596  0.368062  4.5393  2.2819  0.037705
# 17457  2979.4200  24.4099  33.998501  0.368062  4.4872  2.2728  0.038547
# 17458  2979.5724  24.4099  34.077848  0.368062  4.4662  2.2730  0.038599
# 17459  2979.7248  24.4099  33.842925  0.368062  4.3735  2.2731  0.037318
# 17460  2979.8772  24.4099  33.796072  0.368062  4.3489  2.2674  0.035771
#
#        well   log_LLS   log_LLD   LLD-LLS   GR-GKUT
# 0         1  0.699109  0.749381  0.050272  0.298900
# 1         1  0.708140  0.769960  0.061820 -0.657300
# 2         1  0.751779  0.823416  0.071636 -1.046600
# 3         1  0.787269  0.865447  0.078178 -1.465400
# 4         1  0.833886  0.921738  0.087852 -0.209500
# ...     ...       ...       ...       ...       ...
# 17456     3 -0.272377 -0.134245  0.138133 -9.306696
# 17457     3 -0.269783 -0.132356  0.137427 -9.588601
# 17458     3 -0.263922 -0.128077  0.135845 -9.667948
# 17459     3 -0.261378 -0.126215  0.135163 -9.433025
# 17460     3 -0.259558 -0.124881  0.134678 -9.386172
#
# [17461 rows x 12 columns]

# %% [markdown]
# <h5 style="color:rgba(0, 0, 178, 0.6);">Split data to; train and test ; X and y </h5>

# %%
train = df[~df['well'].isin(df.groupby("well").get_group(6)['well'])]
train = train[~train['well'].isin(train.groupby("well").get_group(4)['well'])]
test = df.groupby("well").get_group(6)
val = df.groupby("well").get_group(4)

X_train = train.drop(["NPHI", "RHOB","DRHO", "well"], axis=1)
y_train = train["NPHI"]

X_test = test.drop(["NPHI", "RHOB", "DRHO", "well"], axis=1)
y_test = test["NPHI"]

X_val = val.drop(["NPHI", "RHOB", "DRHO", "well"], axis=1)
y_val = val["NPHI"]

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_val = scaler.transform(X_val)
X_test = scaler.transform(X_test)

# %% [markdown]
# <h5 style="color:rgba(0, 0, 178, 0.6);">Create a function that build a dynamic model that can change the shape of the NN model with hyper parameters(hp) parameters</h5>

# %%
# hp ======> hyper parameters = [number_nuron_layer1, number_nuron_layer2, number_nuron_layer3,
#                          number_nuron_layer4, Activation_fuctin_layer1, Activaiton_function_layer2,
#                     Activation_fuctin_layer3, Activation_fuctin_layer4, If for layer1 have Drop_out=1 else 0,
#         If for layer2 have Drop_out=1 else 0, If for layer3 have Drop_out=1 else 0, If for layer4 have Drop_out=1 else 0,
#     If for layer1 have batch_norm=1 else 0, If for layer2 have batch_norm=1 else 0, If for layer1 have batch_norm=3 else 0,
#                       If for layer1 have batch_norm=1 else 0, learning_rate, batch_size]


# in this function we create a function that can build model that can chane evry time

def dynamic_model(hp, train=train):

    
    activation_function = ["relu","sigmoid","softmax","softsign",
                           "tanh","selu","elu" ,"exponential",
                           "leaky_relu","relu6","silu","gelu",
                           "hard_sigmoid","linear","mish","log_softmax"]
    
    
    input_layer = keras.layers.Input(shape=(8))
    layer1 = keras.layers.Dense(hp[0], activation_function[hp[4]], name="layer1")(input_layer)
    
#     in this sectino we have 4 layer  so that we have 4 section for dscetion that we have in each layer DropOut or BatchNorm
#   this is layer1 we have 4 condition:
    if ((hp[8] == 1) & (hp[12] == 1)):
        drop1 = keras.layers.Dropout(0.3)(layer1)
        norm1 = keras.layers.BatchNormalization()(drop1)
        layer2 = keras.layers.Dense(hp[1], activation_function[hp[5]], name="layer2")(norm1)
    elif ((hp[8] == 1) & (hp[12] == 0)):
        drop1 = keras.layers.Dropout(0.3)(layer1)
        layer2 = keras.layers.Dense(hp[1], activation_function[hp[5]], name="layer2")(drop1)
    elif ((hp[8] == 0) & (hp[12] == 1)):
        norm1 = keras.layers.BatchNormalization()(layer1)
        layer2 = keras.layers.Dense(hp[1], activation_function[hp[5]], name="layer2")(norm1)
    else:
        layer2 = keras.layers.Dense(hp[1], activation_function[hp[5]], name="layer2")(layer1)
        
#    layer2: 
    if ((hp[9] == 1) & (hp[13] == 1)):
        drop2 = keras.layers.Dropout(0.3)(layer2)
        norm2 = keras.layers.BatchNormalization()(drop2)
        layer3 = keras.layers.Dense(hp[2], activation_function[hp[6]], name="layer3")(norm2)
    elif ((hp[9] == 1) & (hp[13] == 0)):
        drop2 = keras.layers.Dropout(0.3)(layer2)
        layer3 = keras.layers.Dense(hp[2], activation_function[hp[6]], name="layer3")(drop2)
    elif ((hp[9] == 0) & (hp[13] == 1)):
        norm2 = keras.layers.BatchNormalization()(layer2)
        layer3 = keras.layers.Dense(hp[2], activation_function[hp[6]], name="layer3")(norm2)
    else:
        layer3 = keras.layers.Dense(hp[2], activation_function[hp[6]], name="layer3")(layer2)
        
#     layer3 :   
    if ((hp[10] == 1) & (hp[14] == 1)):
        drop3 = keras.layers.Dropout(0.3)(layer3)
        norm3 = keras.layers.BatchNormalization()(drop3)
        layer4 = keras.layers.Dense(hp[3], activation_function[hp[7]], name="layer4")(norm3)
    elif ((hp[10] == 1) & (hp[14] == 0)):
        drop3 = keras.layers.Dropout(0.3)(layer3)
        layer4 = keras.layers.Dense(hp[3], activation_function[hp[7]], name="layer4")(drop3)
    elif ((hp[10] == 0) & (hp[14] == 1)):
        norm3 = keras.layers.BatchNormalization()(layer3)
        layer4 = keras.layers.Dense(hp[3], activation_function[hp[7]], name="layer4")(norm3)
    else:
        layer4 = keras.layers.Dense(hp[3], activation_function[hp[7]], name="layer4")(layer3)
        
#    layer4:
    if ((hp[11] == 1) & (hp[15] == 1)):
        drop4 = keras.layers.Dropout(0.3)(layer4)
        norm4 = keras.layers.BatchNormalization()(drop4)
        output_layer = keras.layers.Dense(1, "linear", name="output_layer")(norm4)
    elif ((hp[11] == 1) & (hp[15] == 0)):
        drop4 = keras.layers.Dropout(0.3)(layer4)
        output_layer = keras.layers.Dense(1, "linear", name="output_layer")(drop4)
    elif ((hp[11] == 0) & (hp[15] == 1)):
        norm4 = keras.layers.BatchNormalization()(layer4)
        output_layer = keras.layers.Dense(1, "linear", name="output_layer")(norm4)
    else:
        output_layer = keras.layers.Dense(1, "linear", name="output_layer")(layer4)
        
#     at last we create final model
    model = keras.Model(inputs=input_layer, outputs=output_layer)
    
#     in this section we complie the model
    optimizer =keras.optimizers.Adamax(learning_rate=hp[16])
    model.compile(loss="mae", optimizer=optimizer, metrics=["mse"])

    # wright the callbacks that we need
#     checkpoint_cb = tf.keras.callbacks.ModelCheckpoint("my_checkpoints.h5", save_weights_only=True,best_only=True)
    early_stopping_cb = keras.callbacks.EarlyStopping(patience=30, restore_best_weights=True)
    
    # fit the model
    history = model.fit(X_train,
                         y_train, 
                        validation_data=(X_val, y_val),
                        callbacks=[early_stopping_cb],
                        batch_size=hp[17],
                        epochs=1000,
                        verbose=0)
    
# for chace the model we prdiction x_val
    val_pred = model.predict(X_val)
#   because we r2_score dont work with nan values we chane nan value with -999
    val_pred[np.isnan(val_pred)] = -999
        
    solution_fitness = r2_score(y_val, val_pred)
            
    return model, solution_fitness

# %% [markdown]
# <h5 style="color:rgba(0, 0, 178, 0.6);">Create a function that build randomly DNA for obtimizer</h5>

# %%
def hp_creator(num_solutions=50):
    hps = pd.DataFrame(columns=[
                                "nurn1","nurn2","nurn3","nurn4",
                                "Active1","Active2","Active3","Active4",
                                "Drop1", "Drop2", "Drop3", "Drop4",
                                "Norm1", "Norm2", "Norm3", "Norm4",
                                "Learn_rate", "batch_size", "solution_fitness"
                               ])
    
    hps["nurn1"], hps["nurn2"] = [random.randint(10, 150) for _ in range(num_solutions)], [random.randint(10, 150) for _ in range(num_solutions)]
    hps["nurn3"], hps["nurn4"] = [random.randint(10, 150) for _ in range(num_solutions)], [random.randint(10, 150) for _ in range(num_solutions)]
    
    hps["Active1"], hps["Active2"] = [random.randint(0, 15) for _ in range(num_solutions)], [random.randint(0, 15) for _ in range(num_solutions)]
    hps["Active3"], hps["Active4"] = [random.randint(0, 15) for _ in range(num_solutions)], [random.randint(0, 15) for _ in range(num_solutions)]
                                                                                 
    hps["Drop1"], hps["Drop2"] = [random.choice([0, 1]) for _ in range(num_solutions)], [random.choice([0, 1]) for _ in range(num_solutions)]
    hps["Drop3"], hps["Drop4"] = [random.choice([0, 1]) for _ in range(num_solutions)], [random.choice([0, 1]) for _ in range(num_solutions)]
    
    hps["Norm1"], hps["Norm2"] = [random.choice([0, 1]) for _ in range(num_solutions)], [random.choice([0, 1]) for _ in range(num_solutions)]
    hps["Norm3"], hps["Norm4"] = [random.choice([0, 1]) for _ in range(num_solutions)], [random.choice([0, 1]) for _ in range(num_solutions)]
    
    hps["Learn_rate"] = [random.choice([0.001, 0.01, 0.0001, 0.00001, 0.1, 0.000001, 0.0000001]) for _ in range(num_solutions)]
    hps["batch_size"] = [random.randint(30, 300) for _ in range(num_solutions)]
    

    return hps

# %% [markdown]
# <h5 style="color:rgba(0, 0, 178, 0.6);">Create a function that build child DNA from best DNA's for obtimizer</h5>

# %%
def child_creator(parents, num_solutions=50):
    hps = pd.DataFrame(columns=[
                                "nurn1","nurn2","nurn3","nurn4",
                                "Active1","Active2","Active3","Active4",
                                "Drop1", "Drop2", "Drop3", "Drop4",
                                "Norm1", "Norm2", "Norm3", "Norm4",
                                "Learn_rate", "batch_size", "solution_fitness"
                               ])
    
    hps["nurn1"], hps["nurn2"] = [random.choice(parents["nurn1"].values) for _ in range(num_solutions)], [random.choice(parents["nurn2"].values) for _ in range(num_solutions)]
    hps["nurn3"], hps["nurn4"] = [random.choice(parents["nurn3"].values) for _ in range(num_solutions)], [random.choice(parents["nurn4"].values) for _ in range(num_solutions)]
    
    hps["Active1"], hps["Active2"] = [random.choice(parents["Active1"].values) for _ in range(num_solutions)], [random.choice(parents["Active2"].values) for _ in range(num_solutions)]
    hps["Active3"], hps["Active4"] = [random.choice(parents["Active3"].values) for _ in range(num_solutions)], [random.choice(parents["Active4"].values) for _ in range(num_solutions)]
                                                                                 
    hps["Drop1"], hps["Drop2"] = [random.choice(parents["Drop1"].values) for _ in range(num_solutions)], [random.choice(parents["Drop2"].values) for _ in range(num_solutions)]
    hps["Drop3"], hps["Drop4"] = [random.choice(parents["Drop3"].values) for _ in range(num_solutions)], [random.choice(parents["Drop4"].values) for _ in range(num_solutions)]
    
    hps["Norm1"], hps["Norm2"] = [random.choice(parents["Norm1"].values) for _ in range(num_solutions)], [random.choice(parents["Norm2"].values) for _ in range(num_solutions)]
    hps["Norm3"], hps["Norm4"] = [random.choice(parents["Norm3"].values) for _ in range(num_solutions)], [random.choice(parents["Norm4"].values) for _ in range(num_solutions)]
    
    hps["Learn_rate"] = [random.choice(parents["Learn_rate"].values) for _ in range(num_solutions)]
    hps["batch_size"] = [random.choice(parents["batch_size"].values) for _ in range(num_solutions)]
    
    hps = pd.concat([hps, parents], axis=0).reset_index().drop("index", axis=1)
    
    
    return hps

# %% [markdown]
# <h5 style="color:rgba(0, 0, 178, 0.6);">we use obtimizer and dynamic model to find best DNA</h5>

# %%
# we create a DataFrame to save best solutions in it and create child from this best slutions
best_slutions = pd.DataFrame(columns=[
                                "nurn1","nurn2","nurn3","nurn4",
                                "Active1","Active2","Active3","Active4",
                                "Drop1", "Drop2", "Drop3", "Drop4",
                                "Norm1", "Norm2", "Norm3", "Norm4",
                                "Learn_rate", "batch_size", "solution_fitness"
                               ])
# we create 5 times cheild
for i in range(5):
    #for start our work we shoud create random DNA
    if i == 0:
        #_____________________________________________________________________________________
        #create 100 DNA randomly for nex step
        hps = hp_creator(num_solutions=100)
        #check each Random DNAs and bild models to see which models is better
        for j in range(len(hps)):
            _, hps["solution_fitness"][j] = dynamic_model(hps.iloc[j,:])
            print("step: ", j+1, f"    solution_fitness_random{j}: ", hps["solution_fitness"][j])
        #check each models and select that models have positive r2_score
        hps = hps[hps["solution_fitness"]>=0]
        #and sort the DNAs and select 25 best of this DNAs
        hps = hps.sort_values("solution_fitness").reset_index(drop=True)
        #save 25 of best to parents data frame and save the best solution to best_slution data frame
        parents = hps.iloc[len(hps)-25:,:]
        best_slutions = pd.concat([best_slutions, parents.iloc[len(parents)-1:len(parents),:]], axis=0)
        #_______________________________________________________________________________________________
    
    #_____________________________________________________________________________________
    #now we create 100 childs solution form this parents slutions
    childs = child_creator(parents, num_solutions=100)
    for j in range(len(childs)):
        _, childs["solution_fitness"][j] = dynamic_model(childs.iloc[j,:])
        print("step: ", j+1, f"    solution_fitness_child{j}: ", childs["solution_fitness"][j])
        
    childs = childs[childs["solution_fitness"]>=0]
    childs = childs.sort_values("solution_fitness").reset_index(drop=True)
    
    parents = childs.iloc[len(childs)-25:,:]
    best_slutions = pd.concat([best_slutions, parents.iloc[len(parents)-1:,:]], axis=0)
    #___________________________________________________________________________________

# save the best solutions to hard
best_slutions.to_csv("bestmodels.csv")
# Out:
# 38/38 [==============================] - 0s 6ms/step
# step:  1     solution_fitness_random0:  0.30372427569942495
# 38/38 [==============================] - 0s 5ms/step
# step:  2     solution_fitness_random1:  -5.53867361875891
# 38/38 [==============================] - 0s 5ms/step
# step:  3     solution_fitness_random2:  -486.8620701467944
# 38/38 [==============================] - 0s 4ms/step
# step:  4     solution_fitness_random3:  0.6389364164512146
# 38/38 [==============================] - 0s 4ms/step
# step:  5     solution_fitness_random4:  0.6521034959785816
# 38/38 [==============================] - 0s 3ms/step
# step:  6     solution_fitness_random5:  0.62180638059896
# 38/38 [==============================] - 0s 3ms/step
# step:  7     solution_fitness_random6:  0.5614793762618038
# 38/38 [==============================] - 1s 8ms/step
# step:  8     solution_fitness_random7:  0.6480373655004308
# 38/38 [==============================] - 1s 13ms/step
# step:  9     solution_fitness_random8:  0.5378182688870685
# 38/38 [==============================] - 0s 3ms/step
# step:  10     solution_fitness_random9:  0.22215483649979673
# 38/38 [==============================] - 0s 3ms/step
# step:  11     solution_fitness_random10:  -0.09989063977772039
# 38/38 [==============================] - 0s 2ms/step
# step:  12     solution_fitness_random11:  0.5783204942992086
# 38/38 [==============================] - 0s 3ms/step
# step:  13     solution_fitness_random12:  0.5595135873857717
# 38/38 [==============================] - 0s 3ms/step
# step:  14     solution_fitness_random13:  -0.468654006219837
# 38/38 [==============================] - 0s 4ms/step
# step:  15     solution_fitness_random14:  0.3412682138910328
# 38/38 [==============================] - 0s 3ms/step
# step:  16     solution_fitness_random15:  0.6996873396789999
# 38/38 [==============================] - 0s 3ms/step
# step:  17     solution_fitness_random16:  0.6557972667722927
# 38/38 [==============================] - 0s 4ms/step
# step:  18     solution_fitness_random17:  0.4202811324004292
# 38/38 [==============================] - 0s 3ms/step
# step:  19     solution_fitness_random18:  -5.439032844027293
# 38/38 [==============================] - 0s 4ms/step
# step:  20     solution_fitness_random19:  0.6750226029552289
# 38/38 [==============================] - 0s 3ms/step
# step:  21     solution_fitness_random20:  -0.022371910465932787
# 38/38 [==============================] - 0s 4ms/step
# step:  22     solution_fitness_random21:  0.5177523685595293
# 38/38 [==============================] - 0s 3ms/step
# step:  23     solution_fitness_random22:  -22.044075348116454
# 38/38 [==============================] - 0s 2ms/step
# step:  24     solution_fitness_random23:  -2.8095090440626724
# 38/38 [==============================] - 0s 2ms/step
# step:  25     solution_fitness_random24:  0.5048620190224589
# 38/38 [==============================] - 0s 3ms/step
# step:  26     solution_fitness_random25:  0.6463179181883715
# 38/38 [==============================] - 0s 4ms/step
# step:  27     solution_fitness_random26:  0.5898878163710986
# 38/38 [==============================] - 0s 5ms/step
# step:  28     solution_fitness_random27:  0.6625394700532525
# 38/38 [==============================] - 0s 5ms/step
# step:  29     solution_fitness_random28:  0.6555209504800501
# 38/38 [==============================] - 0s 2ms/step
# step:  30     solution_fitness_random29:  0.4809900851444904
# 38/38 [==============================] - 0s 3ms/step
# step:  31     solution_fitness_random30:  0.41789104995082293
# 38/38 [==============================] - 0s 2ms/step
# step:  32     solution_fitness_random31:  0.4174859362476605
# 38/38 [==============================] - 0s 3ms/step
# step:  33     solution_fitness_random32:  -10.147067598921454
# 38/38 [==============================] - 0s 3ms/step
# step:  34     solution_fitness_random33:  -3.3644989140752557
# 38/38 [==============================] - 0s 2ms/step
# step:  35     solution_fitness_random34:  -8.819118824901091
# 38/38 [==============================] - 0s 2ms/step
# step:  36     solution_fitness_random35:  0.5147816495465842
# 38/38 [==============================] - 0s 7ms/step
# step:  37     solution_fitness_random36:  0.6166665706268684
# 38/38 [==============================] - 0s 5ms/step
# step:  38     solution_fitness_random37:  -1.4939894014023016
# 38/38 [==============================] - 0s 2ms/step
# step:  39     solution_fitness_random38:  0.431956410038317
# 38/38 [==============================] - 0s 4ms/step
# step:  40     solution_fitness_random39:  0.6169009650462232
# 38/38 [==============================] - 0s 5ms/step
# step:  41     solution_fitness_random40:  0.6487674116616846
# 38/38 [==============================] - 0s 2ms/step
# step:  42     solution_fitness_random41:  0.6850598720542875
# 38/38 [==============================] - 0s 4ms/step
# step:  43     solution_fitness_random42:  -0.6305556746504335
# 38/38 [==============================] - 0s 3ms/step
# step:  44     solution_fitness_random43:  -2.7365214409638834
# 38/38 [==============================] - 0s 6ms/step
# step:  45     solution_fitness_random44:  0.48883208296374614
# 38/38 [==============================] - 0s 4ms/step
# step:  46     solution_fitness_random45:  -1.1309077629733508
# 38/38 [==============================] - 0s 5ms/step
# step:  47     solution_fitness_random46:  -48.07401939424113
# 38/38 [==============================] - 0s 2ms/step
# step:  48     solution_fitness_random47:  -43.28923377172899
# 38/38 [==============================] - 0s 2ms/step
# step:  49     solution_fitness_random48:  0.6415426951429637
# 38/38 [==============================] - 0s 2ms/step
# step:  50     solution_fitness_random49:  0.19237929443972923
# 38/38 [==============================] - 0s 2ms/step
# step:  51     solution_fitness_random50:  -8.073458505501524
# 38/38 [==============================] - 0s 2ms/step
# step:  52     solution_fitness_random51:  -5.3287912740369086
# 38/38 [==============================] - 0s 2ms/step
# step:  53     solution_fitness_random52:  -37.744949970955645
# 38/38 [==============================] - 0s 2ms/step
# step:  54     solution_fitness_random53:  0.6562706851956082
# 38/38 [==============================] - 0s 1ms/step
# step:  55     solution_fitness_random54:  0.28516374933380606
# 38/38 [==============================] - 0s 2ms/step
# step:  56     solution_fitness_random55:  -0.011524234126938149
# 38/38 [==============================] - 0s 2ms/step
# step:  57     solution_fitness_random56:  -4.844880762103031
# 38/38 [==============================] - 0s 3ms/step
# step:  58     solution_fitness_random57:  0.5976739898373892
# 38/38 [==============================] - 0s 2ms/step
# step:  59     solution_fitness_random58:  0.45218732955414753
# 38/38 [==============================] - 0s 2ms/step
# step:  60     solution_fitness_random59:  0.6932872519360738
# 38/38 [==============================] - 0s 3ms/step
# step:  61     solution_fitness_random60:  -1.4254039346897915
# 38/38 [==============================] - 0s 2ms/step
# step:  62     solution_fitness_random61:  0.6530180891334092
# 38/38 [==============================] - 0s 2ms/step
# step:  63     solution_fitness_random62:  -4.339070283009688
# 38/38 [==============================] - 0s 2ms/step
# step:  64     solution_fitness_random63:  0.6656206131918291
# 38/38 [==============================] - 0s 2ms/step
# step:  65     solution_fitness_random64:  0.619515341586836
# 38/38 [==============================] - 0s 3ms/step
# step:  66     solution_fitness_random65:  -50.48589231688387
# 38/38 [==============================] - 0s 2ms/step
# step:  67     solution_fitness_random66:  -0.49063978588542545
# 38/38 [==============================] - 0s 4ms/step
# step:  68     solution_fitness_random67:  0.6624410200366948
# 38/38 [==============================] - 0s 2ms/step
# step:  69     solution_fitness_random68:  0.5898478563513181
# 38/38 [==============================] - 0s 2ms/step
# step:  70     solution_fitness_random69:  -291936953.7702268
# 38/38 [==============================] - 0s 2ms/step
# step:  71     solution_fitness_random70:  0.7095473274540406
# 38/38 [==============================] - 0s 2ms/step
# step:  72     solution_fitness_random71:  -0.43977478467315034
# 38/38 [==============================] - 0s 2ms/step
# step:  73     solution_fitness_random72:  0.5687709171456721
# 38/38 [==============================] - 0s 2ms/step
# step:  74     solution_fitness_random73:  0.691556104666975
# 38/38 [==============================] - 0s 2ms/step
# step:  75     solution_fitness_random74:  -10.248055769917244
# 38/38 [==============================] - 0s 2ms/step
# step:  76     solution_fitness_random75:  0.48612810958256947
# 38/38 [==============================] - 0s 2ms/step
# step:  77     solution_fitness_random76:  -0.8638566092290101
# 38/38 [==============================] - 0s 2ms/step
# step:  78     solution_fitness_random77:  -291936953.7702268
# 38/38 [==============================] - 0s 2ms/step
# step:  79     solution_fitness_random78:  0.7274165385990554
# 38/38 [==============================] - 0s 2ms/step
# step:  80     solution_fitness_random79:  0.112040158602988
# 38/38 [==============================] - 0s 2ms/step
# step:  81     solution_fitness_random80:  0.6846503721500163
# 38/38 [==============================] - 0s 2ms/step
# step:  82     solution_fitness_random81:  -0.02002160962141164
# 38/38 [==============================] - 0s 2ms/step
# step:  83     solution_fitness_random82:  -15.340056112221308
# 38/38 [==============================] - 0s 5ms/step
# step:  84     solution_fitness_random83:  -0.3142595978775624
# 38/38 [==============================] - 0s 2ms/step
# step:  85     solution_fitness_random84:  0.6235000088259262
# 38/38 [==============================] - 0s 2ms/step
# step:  86     solution_fitness_random85:  -16.571382528599656
# 38/38 [==============================] - 0s 3ms/step
# step:  87     solution_fitness_random86:  0.6563786463664182
# 38/38 [==============================] - 0s 2ms/step
# step:  88     solution_fitness_random87:  0.6511439503822058
# 38/38 [==============================] - 0s 2ms/step
# step:  89     solution_fitness_random88:  0.6797884164911445
# 38/38 [==============================] - 0s 5ms/step
# step:  90     solution_fitness_random89:  -1.9479928534830235
# 38/38 [==============================] - 0s 2ms/step
# step:  91     solution_fitness_random90:  0.6709593035455974
# 38/38 [==============================] - 0s 2ms/step
# step:  92     solution_fitness_random91:  -28.690459413711963
# 38/38 [==============================] - 0s 2ms/step
# step:  93     solution_fitness_random92:  -2.893195084123908
# 38/38 [==============================] - 0s 2ms/step
# step:  94     solution_fitness_random93:  0.36324307006435586
# 38/38 [==============================] - 0s 2ms/step
# step:  95     solution_fitness_random94:  0.4532365104876055
# 38/38 [==============================] - 0s 2ms/step
# step:  96     solution_fitness_random95:  0.5964774260624115
# 38/38 [==============================] - 0s 2ms/step
# step:  97     solution_fitness_random96:  0.692453936641343
# 38/38 [==============================] - 0s 2ms/step
# step:  98     solution_fitness_random97:  0.690904203689989
# 38/38 [==============================] - 0s 2ms/step
# step:  99     solution_fitness_random98:  0.6822321725981384
# 38/38 [==============================] - 0s 2ms/step
# step:  100     solution_fitness_random99:  0.6608693173665839
# 38/38 [==============================] - 0s 1ms/step
# step:  1     solution_fitness_child0:  0.6833016197817358
# 38/38 [==============================] - 0s 2ms/step
# step:  2     solution_fitness_child1:  0.633476885609437
# 38/38 [==============================] - 0s 2ms/step
# step:  3     solution_fitness_child2:  0.6354443074489322
# 38/38 [==============================] - 0s 2ms/step
# step:  4     solution_fitness_child3:  0.6606246275256882
# 38/38 [==============================] - 0s 2ms/step
# step:  5     solution_fitness_child4:  0.11080406873016613
# 38/38 [==============================] - 0s 2ms/step
# step:  6     solution_fitness_child5:  0.6754067703234237
# 38/38 [==============================] - 0s 2ms/step
# step:  7     solution_fitness_child6:  0.5452278038566116
# 38/38 [==============================] - 0s 2ms/step
# step:  8     solution_fitness_child7:  -0.26443467646610563
# 38/38 [==============================] - 0s 2ms/step
# step:  9     solution_fitness_child8:  0.6736267014081704
# 38/38 [==============================] - 0s 2ms/step
# step:  10     solution_fitness_child9:  0.6754476934316817
# 38/38 [==============================] - 0s 4ms/step
# step:  11     solution_fitness_child10:  0.6430081311247591
# 38/38 [==============================] - 0s 3ms/step
# step:  12     solution_fitness_child11:  0.5624484716935645
# 38/38 [==============================] - 0s 2ms/step
# step:  13     solution_fitness_child12:  0.6783510302595721
# 38/38 [==============================] - 0s 2ms/step
# step:  14     solution_fitness_child13:  0.6840033958247432
# 38/38 [==============================] - 0s 2ms/step
# step:  15     solution_fitness_child14:  0.024033024789198776
# 38/38 [==============================] - 0s 1ms/step
# step:  16     solution_fitness_child15:  0.6896344493468044
# 38/38 [==============================] - 0s 2ms/step
# step:  17     solution_fitness_child16:  0.6984338534643366
# 38/38 [==============================] - 0s 2ms/step
# step:  18     solution_fitness_child17:  0.6962465442034247
# 38/38 [==============================] - 0s 2ms/step
# step:  19     solution_fitness_child18:  0.6903606374478591
# 38/38 [==============================] - 0s 2ms/step
# step:  20     solution_fitness_child19:  -0.03691443949948603
# 38/38 [==============================] - 0s 2ms/step
# step:  21     solution_fitness_child20:  0.686307291160756
# 38/38 [==============================] - 0s 1ms/step
# step:  22     solution_fitness_child21:  -0.07051134533832881
# 38/38 [==============================] - 0s 2ms/step
# step:  23     solution_fitness_child22:  -0.1252390100229246
# 38/38 [==============================] - 0s 4ms/step
# step:  24     solution_fitness_child23:  0.6429745169754305
# 38/38 [==============================] - 0s 2ms/step
# step:  25     solution_fitness_child24:  0.6546218517424729
# 38/38 [==============================] - 0s 2ms/step
# step:  26     solution_fitness_child25:  0.6696194978861976
# 38/38 [==============================] - 0s 7ms/step
# step:  27     solution_fitness_child26:  0.6284896600960472
# 38/38 [==============================] - 0s 2ms/step
# step:  28     solution_fitness_child27:  0.6573712545165518
# 38/38 [==============================] - 0s 1ms/step
# step:  29     solution_fitness_child28:  -0.1019670452496424
# 38/38 [==============================] - 0s 2ms/step
# step:  30     solution_fitness_child29:  0.6789205526017201
# 38/38 [==============================] - 0s 1ms/step
# step:  31     solution_fitness_child30:  0.6945539521272523
# 38/38 [==============================] - 0s 2ms/step
# step:  32     solution_fitness_child31:  0.6470590789302899
# 38/38 [==============================] - 0s 2ms/step
# step:  33     solution_fitness_child32:  0.6318180605962618
# 38/38 [==============================] - 0s 2ms/step
# step:  34     solution_fitness_child33:  0.6767955014274782
# 38/38 [==============================] - 0s 3ms/step
# step:  35     solution_fitness_child34:  0.6820314058465407
# 38/38 [==============================] - 0s 2ms/step
# step:  36     solution_fitness_child35:  0.675774338532627
# 38/38 [==============================] - 0s 2ms/step
# step:  37     solution_fitness_child36:  -0.37518109659608845
# 38/38 [==============================] - 0s 2ms/step
# step:  38     solution_fitness_child37:  0.7040072228571738
# 38/38 [==============================] - 0s 2ms/step
# step:  39     solution_fitness_child38:  0.6734868856582685
# 38/38 [==============================] - 0s 2ms/step
# step:  40     solution_fitness_child39:  0.6592041671956264
# 38/38 [==============================] - 0s 1ms/step
# step:  41     solution_fitness_child40:  0.6332882286676316
# 38/38 [==============================] - 0s 2ms/step
# step:  42     solution_fitness_child41:  0.651929176390029
# 38/38 [==============================] - 0s 2ms/step
# step:  43     solution_fitness_child42:  0.6762009991503533
# 38/38 [==============================] - 0s 2ms/step
# step:  44     solution_fitness_child43:  0.6246912383265388
# 38/38 [==============================] - 0s 4ms/step
# step:  45     solution_fitness_child44:  0.6195453215239274
# 38/38 [==============================] - 0s 1ms/step
# step:  46     solution_fitness_child45:  0.67758553782268
# 38/38 [==============================] - 0s 2ms/step
# step:  47     solution_fitness_child46:  0.6791666425726179
# 38/38 [==============================] - 0s 2ms/step
# step:  48     solution_fitness_child47:  0.7006913866082556
# 38/38 [==============================] - 0s 2ms/step
# step:  49     solution_fitness_child48:  -9.083290990099899
# 38/38 [==============================] - 0s 2ms/step
# step:  50     solution_fitness_child49:  0.6407727911136722
# 38/38 [==============================] - 0s 2ms/step
# step:  51     solution_fitness_child50:  0.5988565229277207
# 38/38 [==============================] - 0s 2ms/step
# step:  52     solution_fitness_child51:  0.7020752578728711
# 38/38 [==============================] - 0s 1ms/step
# step:  53     solution_fitness_child52:  -11.782348803731214
# 38/38 [==============================] - 0s 2ms/step
# step:  54     solution_fitness_child53:  0.5631627048129102
# 38/38 [==============================] - 0s 4ms/step
# step:  55     solution_fitness_child54:  0.6987658883070393
# 38/38 [==============================] - 0s 2ms/step
# step:  56     solution_fitness_child55:  0.6913025621294473
# 38/38 [==============================] - 0s 2ms/step
# step:  57     solution_fitness_child56:  0.7061441964035554
# 38/38 [==============================] - 0s 1ms/step
# step:  58     solution_fitness_child57:  0.6495830190402425
# 38/38 [==============================] - 0s 2ms/step
# step:  59     solution_fitness_child58:  0.5861076957806469
# 38/38 [==============================] - 0s 1ms/step
# step:  60     solution_fitness_child59:  0.6812987253636724
# 38/38 [==============================] - 0s 2ms/step
# step:  61     solution_fitness_child60:  -1.6448646866003926
# 38/38 [==============================] - 0s 2ms/step
# step:  62     solution_fitness_child61:  0.6854039359199486
# 38/38 [==============================] - 0s 1ms/step
# step:  63     solution_fitness_child62:  0.6882136932944358
# 38/38 [==============================] - 0s 2ms/step
# step:  64     solution_fitness_child63:  0.26141330199842594
# 38/38 [==============================] - 0s 2ms/step
# step:  65     solution_fitness_child64:  0.677009401589822
# 38/38 [==============================] - 0s 2ms/step
# step:  66     solution_fitness_child65:  0.6885463102840308
# 38/38 [==============================] - 0s 2ms/step
# step:  67     solution_fitness_child66:  0.6782065412457869
# 38/38 [==============================] - 0s 7ms/step
# step:  68     solution_fitness_child67:  0.6654307925277936
# 38/38 [==============================] - 0s 4ms/step
# step:  69     solution_fitness_child68:  -4.264163732412477
# 38/38 [==============================] - 0s 1ms/step
# step:  70     solution_fitness_child69:  0.5224913340680968
# 38/38 [==============================] - 0s 2ms/step
# step:  71     solution_fitness_child70:  0.629306739124314
# 38/38 [==============================] - 0s 1ms/step
# step:  72     solution_fitness_child71:  0.5968851073915031
# 38/38 [==============================] - 0s 2ms/step
# step:  73     solution_fitness_child72:  0.6826123973311746
# 38/38 [==============================] - 0s 2ms/step
# step:  74     solution_fitness_child73:  0.6382846367076812
# 38/38 [==============================] - 0s 2ms/step
# step:  75     solution_fitness_child74:  0.6914210580681228
# 38/38 [==============================] - 0s 1ms/step
# step:  76     solution_fitness_child75:  0.608513524383703
# 38/38 [==============================] - 0s 2ms/step
# step:  77     solution_fitness_child76:  0.5796985249551629
# 38/38 [==============================] - 0s 1ms/step
# step:  78     solution_fitness_child77:  0.6139465886891012
# 38/38 [==============================] - 0s 2ms/step
# step:  79     solution_fitness_child78:  0.6335919018551257
# 38/38 [==============================] - 0s 1ms/step
# step:  80     solution_fitness_child79:  0.5385220277599739
# 38/38 [==============================] - 0s 2ms/step
# step:  81     solution_fitness_child80:  0.682042163059736
# 38/38 [==============================] - 0s 2ms/step
# step:  82     solution_fitness_child81:  0.6799622041409192
# 38/38 [==============================] - 0s 2ms/step
# step:  83     solution_fitness_child82:  0.6646403619691984
# 38/38 [==============================] - 0s 1ms/step
# step:  84     solution_fitness_child83:  0.5560193009140694
# 38/38 [==============================] - 0s 2ms/step
# step:  85     solution_fitness_child84:  0.642772780244866
# 38/38 [==============================] - 0s 2ms/step
# step:  86     solution_fitness_child85:  0.5714437702016858
# 38/38 [==============================] - 0s 2ms/step
# step:  87     solution_fitness_child86:  0.6612591943214875
# 38/38 [==============================] - 0s 2ms/step
# step:  88     solution_fitness_child87:  0.6572725508843221
# 38/38 [==============================] - 0s 2ms/step
# step:  89     solution_fitness_child88:  0.6962217969716066
# 38/38 [==============================] - 0s 4ms/step
# step:  90     solution_fitness_child89:  -1.0171532450382825
# 38/38 [==============================] - 0s 2ms/step
# step:  91     solution_fitness_child90:  0.6977887918627403
# 38/38 [==============================] - 0s 2ms/step
# step:  92     solution_fitness_child91:  0.28101906505832497
# 38/38 [==============================] - 0s 2ms/step
# step:  93     solution_fitness_child92:  0.6588840606505021
# 38/38 [==============================] - 0s 1ms/step
# step:  94     solution_fitness_child93:  0.6578716491108507
# 38/38 [==============================] - 0s 2ms/step
# step:  95     solution_fitness_child94:  0.7000364653244548
# 38/38 [==============================] - 1s 8ms/step
# step:  96     solution_fitness_child95:  0.6617837859720548
# 38/38 [==============================] - 0s 2ms/step
# step:  97     solution_fitness_child96:  0.6805052486300072
# 38/38 [==============================] - 0s 2ms/step
# step:  98     solution_fitness_child97:  0.6337191618001445
# 38/38 [==============================] - 0s 2ms/step
# step:  99     solution_fitness_child98:  0.5962238965820983
# 38/38 [==============================] - 0s 2ms/step
# step:  100     solution_fitness_child99:  0.6771675240899592
# 38/38 [==============================] - 0s 5ms/step
# step:  101     solution_fitness_child100:  0.6638161023277891
# 38/38 [==============================] - 0s 2ms/step
# step:  102     solution_fitness_child101:  0.6800927816932203
# 38/38 [==============================] - 0s 1ms/step
# step:  103     solution_fitness_child102:  0.5973268672722253
# 38/38 [==============================] - 0s 2ms/step
# step:  104     solution_fitness_child103:  0.6574770823860667
# 38/38 [==============================] - 0s 1ms/step
# step:  105     solution_fitness_child104:  -1.482112747419301
# 38/38 [==============================] - 0s 2ms/step
# step:  106     solution_fitness_child105:  0.6487023785170362
# 38/38 [==============================] - 0s 2ms/step
# step:  107     solution_fitness_child106:  0.5785791414668235
# 38/38 [==============================] - 0s 2ms/step
# step:  108     solution_fitness_child107:  0.6417527294550704
# 38/38 [==============================] - 0s 2ms/step
# step:  109     solution_fitness_child108:  0.6514159350317312
# 38/38 [==============================] - 0s 4ms/step
# step:  110     solution_fitness_child109:  0.6554745411467202
# 38/38 [==============================] - 0s 2ms/step
# step:  111     solution_fitness_child110:  0.6638880748765528
# 38/38 [==============================] - 0s 2ms/step
# step:  112     solution_fitness_child111:  0.6252874913731468
# 38/38 [==============================] - 0s 2ms/step
# step:  113     solution_fitness_child112:  0.6907452605688122
# 38/38 [==============================] - 0s 2ms/step
# step:  114     solution_fitness_child113:  0.6944528931872689
# 38/38 [==============================] - 0s 3ms/step
# step:  115     solution_fitness_child114:  0.6572270438262316
# 38/38 [==============================] - 0s 2ms/step
# step:  116     solution_fitness_child115:  0.652126165432029
# 38/38 [==============================] - 0s 2ms/step
# step:  117     solution_fitness_child116:  0.6814409313607472
# 38/38 [==============================] - 0s 2ms/step
# step:  118     solution_fitness_child117:  0.6560636408863514
# 38/38 [==============================] - 0s 2ms/step
# step:  119     solution_fitness_child118:  0.6936911343676532
# 38/38 [==============================] - 0s 2ms/step
# step:  120     solution_fitness_child119:  0.7101289697193369
# 38/38 [==============================] - 0s 2ms/step
# step:  121     solution_fitness_child120:  0.7108409558784534
# 38/38 [==============================] - 0s 2ms/step
# step:  122     solution_fitness_child121:  0.69494306582484
# 38/38 [==============================] - 0s 1ms/step
# step:  123     solution_fitness_child122:  0.6951778315879198
# 38/38 [==============================] - 0s 1ms/step
# step:  124     solution_fitness_child123:  0.6145817269549656
# 38/38 [==============================] - 0s 2ms/step
# step:  125     solution_fitness_child124:  0.7249188110979086
# 38/38 [==============================] - 0s 2ms/step
# step:  1     solution_fitness_child0:  0.6393286186756593
# 38/38 [==============================] - 0s 2ms/step
# step:  2     solution_fitness_child1:  0.6551800221839077
# 38/38 [==============================] - 0s 2ms/step
# step:  3     solution_fitness_child2:  0.5526144191396715
# 38/38 [==============================] - 0s 2ms/step
# step:  4     solution_fitness_child3:  0.5519277984369677
# 38/38 [==============================] - 0s 1ms/step
# step:  5     solution_fitness_child4:  0.7113955668152476
# 38/38 [==============================] - 0s 2ms/step
# step:  6     solution_fitness_child5:  0.4482969306255884
# 38/38 [==============================] - 0s 2ms/step
# step:  7     solution_fitness_child6:  0.6681757962211605
# 38/38 [==============================] - 0s 2ms/step
# step:  8     solution_fitness_child7:  0.5878005788632776
# 38/38 [==============================] - 0s 2ms/step
# step:  9     solution_fitness_child8:  0.4242915049194358
# 38/38 [==============================] - 0s 2ms/step
# step:  10     solution_fitness_child9:  0.6668419483899375
# 38/38 [==============================] - 0s 2ms/step
# step:  11     solution_fitness_child10:  0.6735972946378457
# 38/38 [==============================] - 0s 2ms/step
# step:  12     solution_fitness_child11:  0.6790893279051128
# 38/38 [==============================] - 0s 2ms/step
# step:  13     solution_fitness_child12:  0.6998792604603818
# 38/38 [==============================] - 0s 1ms/step
# step:  14     solution_fitness_child13:  0.665806028357142
# 38/38 [==============================] - 0s 2ms/step
# step:  15     solution_fitness_child14:  0.6404519266986397
# 38/38 [==============================] - 0s 2ms/step
# step:  16     solution_fitness_child15:  0.6808199760336442
# 38/38 [==============================] - 0s 2ms/step
# step:  17     solution_fitness_child16:  0.5748685258270877
# 38/38 [==============================] - 0s 2ms/step
# step:  18     solution_fitness_child17:  0.6454726145607972
# 38/38 [==============================] - 0s 2ms/step
# step:  19     solution_fitness_child18:  0.6702474400143761
# 38/38 [==============================] - 0s 2ms/step
# step:  20     solution_fitness_child19:  0.5359429403622341
# 38/38 [==============================] - 0s 2ms/step
# step:  21     solution_fitness_child20:  0.6697113042692036
# 38/38 [==============================] - 0s 2ms/step
# step:  22     solution_fitness_child21:  0.6676881061548379
# 38/38 [==============================] - 0s 1ms/step
# step:  23     solution_fitness_child22:  0.6803892089475099
# 38/38 [==============================] - 0s 2ms/step
# step:  24     solution_fitness_child23:  0.6063694020591888
# 38/38 [==============================] - 0s 2ms/step
# step:  25     solution_fitness_child24:  0.5519868333492143
# 38/38 [==============================] - 0s 2ms/step
# step:  26     solution_fitness_child25:  0.7314885128747466
# 38/38 [==============================] - 0s 2ms/step
# step:  27     solution_fitness_child26:  0.7177611357028617
# 38/38 [==============================] - 0s 2ms/step
# step:  28     solution_fitness_child27:  0.6654404318263284
# 38/38 [==============================] - 0s 2ms/step
# step:  29     solution_fitness_child28:  0.6975319017324351
# 38/38 [==============================] - 0s 4ms/step
# step:  30     solution_fitness_child29:  0.5779352412371054
# 38/38 [==============================] - 0s 3ms/step
# step:  31     solution_fitness_child30:  0.6818576907373323
# 38/38 [==============================] - 0s 2ms/step
# step:  32     solution_fitness_child31:  0.6299105438914796
# 38/38 [==============================] - 0s 2ms/step
# step:  33     solution_fitness_child32:  0.7226986913489779
# 38/38 [==============================] - 0s 2ms/step
# step:  34     solution_fitness_child33:  0.6937062528136066
# 38/38 [==============================] - 0s 2ms/step
# step:  35     solution_fitness_child34:  0.5638762787000127
# 38/38 [==============================] - 0s 2ms/step
# step:  36     solution_fitness_child35:  0.6479458720950086
# 38/38 [==============================] - 0s 2ms/step
# step:  37     solution_fitness_child36:  0.6263099240084506
# 38/38 [==============================] - 0s 2ms/step
# step:  38     solution_fitness_child37:  0.6398029334079006
# 38/38 [==============================] - 0s 2ms/step
# step:  39     solution_fitness_child38:  0.6843772534539738
# 38/38 [==============================] - 0s 2ms/step
# step:  40     solution_fitness_child39:  0.6812322271409401
# 38/38 [==============================] - 0s 3ms/step
# step:  41     solution_fitness_child40:  0.6882488860458476
# 38/38 [==============================] - 0s 3ms/step
# step:  42     solution_fitness_child41:  0.6877098034856043
# 38/38 [==============================] - 0s 2ms/step
# step:  43     solution_fitness_child42:  0.7101165874685841
# 38/38 [==============================] - 0s 3ms/step
# step:  44     solution_fitness_child43:  0.6423783191571796
# 38/38 [==============================] - 0s 2ms/step
# step:  45     solution_fitness_child44:  0.6637004284897622
# 38/38 [==============================] - 0s 2ms/step
# step:  46     solution_fitness_child45:  0.6565283397898879
# 38/38 [==============================] - 0s 2ms/step
# step:  47     solution_fitness_child46:  0.6825108908936135
# 38/38 [==============================] - 0s 3ms/step
# step:  48     solution_fitness_child47:  0.6848213089050869
# 38/38 [==============================] - 0s 4ms/step
# step:  49     solution_fitness_child48:  0.6746197960991
# 38/38 [==============================] - 1s 3ms/step
# step:  50     solution_fitness_child49:  0.6224023655925279
# 38/38 [==============================] - 2s 8ms/step
# step:  51     solution_fitness_child50:  0.6861840181821558
# 38/38 [==============================] - 0s 3ms/step
# step:  52     solution_fitness_child51:  0.5827730268942068
# 38/38 [==============================] - 0s 2ms/step
# step:  53     solution_fitness_child52:  0.6478908828175969
# 38/38 [==============================] - 1s 5ms/step
# step:  54     solution_fitness_child53:  0.5738565612747181
# 38/38 [==============================] - 0s 3ms/step
# step:  55     solution_fitness_child54:  -1.011474096473361
# 38/38 [==============================] - 0s 2ms/step
# step:  56     solution_fitness_child55:  0.6897423656651329
# 38/38 [==============================] - 0s 3ms/step
# step:  57     solution_fitness_child56:  0.6266010396598183
# 38/38 [==============================] - 1s 9ms/step
# step:  58     solution_fitness_child57:  0.7048360740960161
# 38/38 [==============================] - 1s 11ms/step
# step:  59     solution_fitness_child58:  0.6331129357587038
# 38/38 [==============================] - 0s 2ms/step
# step:  60     solution_fitness_child59:  0.6795818465997003
# 38/38 [==============================] - 0s 2ms/step
# step:  61     solution_fitness_child60:  0.6949945402317838
# 38/38 [==============================] - 0s 3ms/step
# step:  62     solution_fitness_child61:  0.6292687370477512
# 38/38 [==============================] - 0s 2ms/step
# step:  63     solution_fitness_child62:  0.6833602950014874
# 38/38 [==============================] - 0s 2ms/step
# step:  64     solution_fitness_child63:  0.5447047955534617
# 38/38 [==============================] - 0s 2ms/step
# step:  65     solution_fitness_child64:  0.7045991495164545
# 38/38 [==============================] - 0s 2ms/step
# step:  66     solution_fitness_child65:  0.6076529127837595
# 38/38 [==============================] - 0s 2ms/step
# step:  67     solution_fitness_child66:  0.666481431905554
# 38/38 [==============================] - 0s 2ms/step
# step:  68     solution_fitness_child67:  0.6577840725054603
# 38/38 [==============================] - 0s 2ms/step
# step:  69     solution_fitness_child68:  0.5397524616212338
# 38/38 [==============================] - 0s 2ms/step
# step:  70     solution_fitness_child69:  0.6743584958539732
# 38/38 [==============================] - 0s 2ms/step
# step:  71     solution_fitness_child70:  0.6365243930535963
# 38/38 [==============================] - 0s 2ms/step
# step:  72     solution_fitness_child71:  0.681333561288076
# 38/38 [==============================] - 0s 3ms/step
# step:  73     solution_fitness_child72:  0.67416051011184
# 38/38 [==============================] - 0s 5ms/step
# step:  74     solution_fitness_child73:  0.7025809917897117
# 38/38 [==============================] - 0s 4ms/step
# step:  75     solution_fitness_child74:  0.6623932333385658
# 38/38 [==============================] - 0s 4ms/step
# step:  76     solution_fitness_child75:  0.633455199646952
# 38/38 [==============================] - 0s 6ms/step
# step:  77     solution_fitness_child76:  0.6655469551629047
# 38/38 [==============================] - 0s 3ms/step
# step:  78     solution_fitness_child77:  0.6476135035517482
# 38/38 [==============================] - 0s 4ms/step
# step:  79     solution_fitness_child78:  0.7036312479209281
# 38/38 [==============================] - 0s 7ms/step
# step:  80     solution_fitness_child79:  0.6575827636344898
# 38/38 [==============================] - 0s 6ms/step
# step:  81     solution_fitness_child80:  0.6423575618831057
# 38/38 [==============================] - 0s 3ms/step
# step:  82     solution_fitness_child81:  0.6761085889206846
# 38/38 [==============================] - 0s 5ms/step
# step:  83     solution_fitness_child82:  0.6398768595436656
# 38/38 [==============================] - 0s 3ms/step
# step:  84     solution_fitness_child83:  0.6820368035320516
# 38/38 [==============================] - 0s 7ms/step
# step:  85     solution_fitness_child84:  0.5666084367017012
# 38/38 [==============================] - 0s 4ms/step
# step:  86     solution_fitness_child85:  0.6685190181958698
# 38/38 [==============================] - 0s 2ms/step
# step:  87     solution_fitness_child86:  0.6942745447321824
# 38/38 [==============================] - 0s 7ms/step
# step:  88     solution_fitness_child87:  0.6792461271997048
# 38/38 [==============================] - 1s 9ms/step
# step:  89     solution_fitness_child88:  0.6683922228684162
# 38/38 [==============================] - 1s 18ms/step
# step:  90     solution_fitness_child89:  0.6815793728329549
# 38/38 [==============================] - 0s 3ms/step
# step:  91     solution_fitness_child90:  0.6691937965809214
# 38/38 [==============================] - 0s 4ms/step
# step:  92     solution_fitness_child91:  0.6463374066589254
# 38/38 [==============================] - 0s 5ms/step
# step:  93     solution_fitness_child92:  0.4139514938963036
# 38/38 [==============================] - 0s 4ms/step
# step:  94     solution_fitness_child93:  0.6113504560854369
# 38/38 [==============================] - 0s 3ms/step
# step:  95     solution_fitness_child94:  0.5681960209338655
# 38/38 [==============================] - 0s 6ms/step
# step:  96     solution_fitness_child95:  0.5329412383245825
# 38/38 [==============================] - 0s 5ms/step
# step:  97     solution_fitness_child96:  0.4289431802275623
# 38/38 [==============================] - 0s 4ms/step
# step:  98     solution_fitness_child97:  0.6659491986308295
# 38/38 [==============================] - 0s 4ms/step
# step:  99     solution_fitness_child98:  0.682554111110398
# 38/38 [==============================] - 0s 5ms/step
# step:  100     solution_fitness_child99:  0.6335049462026822
# 38/38 [==============================] - 0s 2ms/step
# step:  101     solution_fitness_child100:  0.7143205060215874
# 38/38 [==============================] - 0s 4ms/step
# step:  102     solution_fitness_child101:  0.6643824561796835
# 38/38 [==============================] - 0s 4ms/step
# step:  103     solution_fitness_child102:  0.6827984958827882
# 38/38 [==============================] - 0s 3ms/step
# step:  104     solution_fitness_child103:  0.6008787139809476
# 38/38 [==============================] - 0s 4ms/step
# step:  105     solution_fitness_child104:  0.6961107206097205
# 38/38 [==============================] - 0s 1ms/step
# step:  106     solution_fitness_child105:  0.6960411450470325
# 38/38 [==============================] - 0s 2ms/step
# step:  107     solution_fitness_child106:  0.5220485740418802
# 38/38 [==============================] - 0s 2ms/step
# step:  108     solution_fitness_child107:  0.6796074426115013
# 38/38 [==============================] - 0s 2ms/step
# step:  109     solution_fitness_child108:  0.6665310504892259
# 38/38 [==============================] - 0s 2ms/step
# step:  110     solution_fitness_child109:  0.690369501954925
# 38/38 [==============================] - 0s 2ms/step
# step:  111     solution_fitness_child110:  0.7005150426572395
# 38/38 [==============================] - 0s 2ms/step
# step:  112     solution_fitness_child111:  0.6796857592095806
# 38/38 [==============================] - 0s 3ms/step
# step:  113     solution_fitness_child112:  0.6865783191039907
# 38/38 [==============================] - 0s 1ms/step
# step:  114     solution_fitness_child113:  0.6761067557889103
# 38/38 [==============================] - 0s 2ms/step
# step:  115     solution_fitness_child114:  0.7010385400686305
# 38/38 [==============================] - 0s 2ms/step
# step:  116     solution_fitness_child115:  0.5405186762280771
# 38/38 [==============================] - 0s 4ms/step
# step:  117     solution_fitness_child116:  0.6850775579743082
# 38/38 [==============================] - 0s 2ms/step
# step:  118     solution_fitness_child117:  0.6868490864492891
# 38/38 [==============================] - 0s 2ms/step
# step:  119     solution_fitness_child118:  0.6641493569463015
# 38/38 [==============================] - 0s 3ms/step
# step:  120     solution_fitness_child119:  0.7004498979691006
# 38/38 [==============================] - 0s 3ms/step
# step:  121     solution_fitness_child120:  0.6768576694892083
# 38/38 [==============================] - 0s 2ms/step
# step:  122     solution_fitness_child121:  0.5910203618420541
# 38/38 [==============================] - 0s 2ms/step
# step:  123     solution_fitness_child122:  0.701155848329621
# 38/38 [==============================] - 0s 1ms/step
# step:  124     solution_fitness_child123:  0.6961686509876144
# 38/38 [==============================] - 0s 2ms/step
# step:  125     solution_fitness_child124:  0.7063463344785854
# 38/38 [==============================] - 0s 2ms/step
# step:  1     solution_fitness_child0:  0.6877349973211171
# 38/38 [==============================] - 0s 2ms/step
# step:  2     solution_fitness_child1:  0.6120558170967639
# 38/38 [==============================] - 0s 2ms/step
# step:  3     solution_fitness_child2:  0.6847069636123206
# 38/38 [==============================] - 0s 2ms/step
# step:  4     solution_fitness_child3:  0.6920130565615474
# 38/38 [==============================] - 0s 2ms/step
# step:  5     solution_fitness_child4:  0.5627363727317505
# 38/38 [==============================] - 0s 2ms/step
# step:  6     solution_fitness_child5:  0.7064283273804821
# 38/38 [==============================] - 0s 1ms/step
# step:  7     solution_fitness_child6:  0.6675609856682904
# 38/38 [==============================] - 0s 2ms/step
# step:  8     solution_fitness_child7:  0.6837926246322735
# 38/38 [==============================] - 0s 2ms/step
# step:  9     solution_fitness_child8:  0.6525810468621631
# 38/38 [==============================] - 0s 2ms/step
# step:  10     solution_fitness_child9:  0.6478004726919862
# 38/38 [==============================] - 0s 2ms/step
# step:  11     solution_fitness_child10:  0.6821524338925425
# 38/38 [==============================] - 0s 2ms/step
# step:  12     solution_fitness_child11:  0.6513478922573948
# 38/38 [==============================] - 0s 2ms/step
# step:  13     solution_fitness_child12:  0.6340490758501613
# 38/38 [==============================] - 0s 1ms/step
# step:  14     solution_fitness_child13:  0.668020897546364
# 38/38 [==============================] - 0s 2ms/step
# step:  15     solution_fitness_child14:  0.6025265536638199
# 38/38 [==============================] - 0s 2ms/step
# step:  16     solution_fitness_child15:  0.56046911001679
# 38/38 [==============================] - 0s 1ms/step
# step:  17     solution_fitness_child16:  0.6473080031698892
# 38/38 [==============================] - 0s 2ms/step
# step:  18     solution_fitness_child17:  0.6946378548270506
# 38/38 [==============================] - 0s 2ms/step
# step:  19     solution_fitness_child18:  0.6568248071175156
# 38/38 [==============================] - 0s 2ms/step
# step:  20     solution_fitness_child19:  0.6492509855545343
# 38/38 [==============================] - 0s 2ms/step
# step:  21     solution_fitness_child20:  0.6680031500026387
# 38/38 [==============================] - 0s 1ms/step
# step:  22     solution_fitness_child21:  0.6875366570759367
# 38/38 [==============================] - 1s 13ms/step
# step:  23     solution_fitness_child22:  0.6842114765326285
# 38/38 [==============================] - 0s 2ms/step
# step:  24     solution_fitness_child23:  0.651164565139302
# 38/38 [==============================] - 0s 2ms/step
# step:  25     solution_fitness_child24:  0.6639390975934292
# 38/38 [==============================] - 0s 4ms/step
# step:  26     solution_fitness_child25:  0.6853821675874842
# 38/38 [==============================] - 0s 2ms/step
# step:  27     solution_fitness_child26:  0.6831787353229742
# 38/38 [==============================] - 0s 2ms/step
# step:  28     solution_fitness_child27:  0.6719767894206349
# 38/38 [==============================] - 0s 2ms/step
# step:  29     solution_fitness_child28:  0.6679687054183381
# 38/38 [==============================] - 0s 2ms/step
# step:  30     solution_fitness_child29:  0.6816870446145198
# 38/38 [==============================] - 0s 2ms/step
# step:  31     solution_fitness_child30:  0.629844814908844
# 38/38 [==============================] - 0s 2ms/step
# step:  32     solution_fitness_child31:  0.671266442574762
# 38/38 [==============================] - 0s 2ms/step
# step:  33     solution_fitness_child32:  0.5962099384896415
# 38/38 [==============================] - 0s 2ms/step
# step:  34     solution_fitness_child33:  0.6912372866239711
# 38/38 [==============================] - 0s 1ms/step
# step:  35     solution_fitness_child34:  0.5610183462845567
# 38/38 [==============================] - 0s 2ms/step
# step:  36     solution_fitness_child35:  0.6896717786434247
# 38/38 [==============================] - 0s 2ms/step
# step:  37     solution_fitness_child36:  0.5930237874331628
# 38/38 [==============================] - 0s 2ms/step
# step:  38     solution_fitness_child37:  0.6371987762104536
# 38/38 [==============================] - 0s 2ms/step
# step:  39     solution_fitness_child38:  0.5568469298053078
# 38/38 [==============================] - 0s 2ms/step
# step:  40     solution_fitness_child39:  0.6925030495701048
# 38/38 [==============================] - 1s 9ms/step
# step:  41     solution_fitness_child40:  0.6899644220854932
# 38/38 [==============================] - 1s 5ms/step
# step:  42     solution_fitness_child41:  0.6833721706266072
# 38/38 [==============================] - 0s 4ms/step
# step:  43     solution_fitness_child42:  0.6881543904079856
# 38/38 [==============================] - 0s 2ms/step
# step:  44     solution_fitness_child43:  0.6480453974738671
# 38/38 [==============================] - 0s 2ms/step
# step:  45     solution_fitness_child44:  0.7048620998158808
# 38/38 [==============================] - 1s 6ms/step
# step:  46     solution_fitness_child45:  0.5965527902659274
# 38/38 [==============================] - 0s 5ms/step
# step:  47     solution_fitness_child46:  0.6195773698839403
# 38/38 [==============================] - 0s 3ms/step
# step:  48     solution_fitness_child47:  0.6980970345250662
# 38/38 [==============================] - 0s 6ms/step
# step:  49     solution_fitness_child48:  0.7021554909961402
# 38/38 [==============================] - 1s 5ms/step
# step:  50     solution_fitness_child49:  0.6893731122218197
# 38/38 [==============================] - 1s 14ms/step
# step:  51     solution_fitness_child50:  0.7105145653246794
# 38/38 [==============================] - 1s 12ms/step
# step:  52     solution_fitness_child51:  0.5822869445023816
# 38/38 [==============================] - 1s 12ms/step
# step:  53     solution_fitness_child52:  0.6702821363597384
# 38/38 [==============================] - 1s 9ms/step
# step:  54     solution_fitness_child53:  0.6922392301200391
# 38/38 [==============================] - 1s 10ms/step
# step:  55     solution_fitness_child54:  0.6817208313854803
# 38/38 [==============================] - 1s 9ms/step
# step:  56     solution_fitness_child55:  0.6713695608529406
# 38/38 [==============================] - 2s 25ms/step
# step:  57     solution_fitness_child56:  0.577120160078146
# 38/38 [==============================] - 1s 6ms/step
# step:  58     solution_fitness_child57:  0.6585015887303519
# 38/38 [==============================] - 1s 9ms/step
# step:  59     solution_fitness_child58:  0.6560974815385399
# 38/38 [==============================] - 1s 6ms/step
# step:  60     solution_fitness_child59:  0.6869067014093024
# 38/38 [==============================] - 1s 6ms/step
# step:  61     solution_fitness_child60:  0.634548354096291
# 38/38 [==============================] - 1s 10ms/step
# step:  62     solution_fitness_child61:  0.6614388561198857
# 38/38 [==============================] - 1s 5ms/step
# step:  63     solution_fitness_child62:  0.6590724236372272
# 38/38 [==============================] - 1s 17ms/step
# step:  64     solution_fitness_child63:  0.6700623764011585
# 38/38 [==============================] - 1s 8ms/step
# step:  65     solution_fitness_child64:  0.6343606601391323
# 38/38 [==============================] - 2s 26ms/step
# step:  66     solution_fitness_child65:  0.6955702805290447
# 38/38 [==============================] - 1s 12ms/step
# step:  67     solution_fitness_child66:  0.6835325281342204
# 38/38 [==============================] - 1s 8ms/step
# step:  68     solution_fitness_child67:  0.6960812928275923
# 38/38 [==============================] - 1s 9ms/step
# step:  69     solution_fitness_child68:  0.6767577415681124
# 38/38 [==============================] - 1s 9ms/step
# step:  70     solution_fitness_child69:  0.6639276744407839
# 38/38 [==============================] - 1s 10ms/step
# step:  71     solution_fitness_child70:  0.6461058881362527
# 38/38 [==============================] - 0s 8ms/step
# step:  72     solution_fitness_child71:  0.6293567204583188
# 38/38 [==============================] - 0s 5ms/step
# step:  73     solution_fitness_child72:  0.6971273288420394
# ...
# 38/38 [==============================] - 0s 2ms/step
# step:  110     solution_fitness_child109:  0.7001755283772706
# 38/38 [==============================] - 0s 2ms/step
# step:  111     solution_fitness_child110:  0.6936689296284492
# 38/38 [==============================] - 0s 2ms/step
# step:  112     solution_fitness_child111:  0.7000712316238265
# 38/38 [==============================] - 0s 2ms/step
# step:  113     solution_fitness_child112:  0.6755325032678453
# 38/38 [==============================] - 0s 2ms/step
# step:  114     solution_fitness_child113:  0.6895947509455551
# 38/38 [==============================] - 0s 2ms/step
# step:  115     solution_fitness_child114:  0.657939232337609
# 38/38 [==============================] - 0s 2ms/step
# step:  116     solution_fitness_child115:  0.7003626505405715
# 38/38 [==============================] - 0s 2ms/step
# step:  117     solution_fitness_child116:  0.6732074271788469
# 38/38 [==============================] - 0s 2ms/step
# step:  118     solution_fitness_child117:  0.6014766041197913
# 38/38 [==============================] - 0s 1ms/step
# step:  119     solution_fitness_child118:  0.6924276538738954
# 38/38 [==============================] - 0s 2ms/step
# step:  120     solution_fitness_child119:  0.5845084602797329
# 38/38 [==============================] - 0s 2ms/step
# step:  121     solution_fitness_child120:  0.7044694330090222
# 38/38 [==============================] - 0s 2ms/step
# step:  122     solution_fitness_child121:  0.7163727655363266
# 38/38 [==============================] - 0s 2ms/step
# step:  123     solution_fitness_child122:  0.70173805006291
# 38/38 [==============================] - 0s 3ms/step
# step:  124     solution_fitness_child123:  0.700391452352062
# 38/38 [==============================] - 0s 2ms/step
# step:  125     solution_fitness_child124:  0.659956395300628
# 38/38 [==============================] - 0s 2ms/step
# step:  1     solution_fitness_child0:  0.673397799776392
# 38/38 [==============================] - 0s 2ms/step
# step:  2     solution_fitness_child1:  0.6727805831804768
# 38/38 [==============================] - 0s 2ms/step
# step:  3     solution_fitness_child2:  0.6903395179550459
# 38/38 [==============================] - 0s 1ms/step
# step:  4     solution_fitness_child3:  0.6988028725252464
# 38/38 [==============================] - 0s 1ms/step
# step:  5     solution_fitness_child4:  0.6742739805935378
# 38/38 [==============================] - 0s 2ms/step
# step:  6     solution_fitness_child5:  0.6454704882131622
# 38/38 [==============================] - 0s 2ms/step
# step:  7     solution_fitness_child6:  0.667801711108793
# 38/38 [==============================] - 0s 2ms/step
# step:  8     solution_fitness_child7:  0.6457574516637328
# 38/38 [==============================] - 0s 2ms/step
# step:  9     solution_fitness_child8:  0.6808656743605896
# 38/38 [==============================] - 0s 2ms/step
# step:  10     solution_fitness_child9:  0.7165009952467336
# 38/38 [==============================] - 0s 2ms/step
# step:  11     solution_fitness_child10:  0.6700720272637908
# 38/38 [==============================] - 0s 2ms/step
# step:  12     solution_fitness_child11:  0.6339644677348985
# 38/38 [==============================] - 0s 2ms/step
# step:  13     solution_fitness_child12:  0.6880482957273286
# 38/38 [==============================] - 0s 2ms/step
# step:  14     solution_fitness_child13:  0.7038185860086437
# 38/38 [==============================] - 0s 2ms/step
# step:  15     solution_fitness_child14:  0.6837321197628745
# 38/38 [==============================] - 0s 2ms/step
# step:  16     solution_fitness_child15:  0.6580687499840285
# 38/38 [==============================] - 0s 2ms/step
# step:  17     solution_fitness_child16:  0.6916890312013033
# 38/38 [==============================] - 1s 2ms/step
# step:  18     solution_fitness_child17:  0.7093858143184644
# 38/38 [==============================] - 0s 1ms/step
# step:  19     solution_fitness_child18:  0.5834449322495303
# 38/38 [==============================] - 0s 2ms/step
# step:  20     solution_fitness_child19:  0.6432215102485015
# 38/38 [==============================] - 0s 1ms/step
# step:  21     solution_fitness_child20:  0.6990881482598106
# 38/38 [==============================] - 0s 2ms/step
# step:  22     solution_fitness_child21:  0.6933269823007142
# 38/38 [==============================] - 0s 1ms/step
# step:  23     solution_fitness_child22:  0.700057544316329
# 38/38 [==============================] - 0s 1ms/step
# step:  24     solution_fitness_child23:  0.6815684056357475
# 38/38 [==============================] - 0s 1ms/step
# step:  25     solution_fitness_child24:  0.6951381000222291
# 38/38 [==============================] - 0s 1ms/step
# step:  26     solution_fitness_child25:  0.6186887893738926
# 38/38 [==============================] - 0s 2ms/step
# step:  27     solution_fitness_child26:  0.531371108289765
# 38/38 [==============================] - 0s 1ms/step
# step:  28     solution_fitness_child27:  0.6773605085878056
# 38/38 [==============================] - 0s 1ms/step
# step:  29     solution_fitness_child28:  0.6756238009361843
# 38/38 [==============================] - 0s 1ms/step
# step:  30     solution_fitness_child29:  0.5080578211025373
# 38/38 [==============================] - 0s 1ms/step
# step:  31     solution_fitness_child30:  0.6756880104466286
# 38/38 [==============================] - 0s 1ms/step
# step:  32     solution_fitness_child31:  0.6866348489478459
# 38/38 [==============================] - 0s 2ms/step
# step:  33     solution_fitness_child32:  0.6841121824309621
# 38/38 [==============================] - 0s 2ms/step
# step:  34     solution_fitness_child33:  0.49537931615399367
# 38/38 [==============================] - 0s 1ms/step
# step:  35     solution_fitness_child34:  0.7036643322011522
# 38/38 [==============================] - 0s 1ms/step
# step:  36     solution_fitness_child35:  0.686410154988504
# 38/38 [==============================] - 0s 2ms/step
# step:  37     solution_fitness_child36:  0.6557832280930367
# 38/38 [==============================] - 0s 1ms/step
# step:  38     solution_fitness_child37:  0.6820478157396038
# 38/38 [==============================] - 1s 2ms/step
# step:  39     solution_fitness_child38:  0.6945573367879504
# 38/38 [==============================] - 0s 1ms/step
# step:  40     solution_fitness_child39:  0.681811461775937
# 38/38 [==============================] - 0s 2ms/step
# step:  41     solution_fitness_child40:  0.7026919479941437
# 38/38 [==============================] - 0s 2ms/step
# step:  42     solution_fitness_child41:  0.6807928358124395
# 38/38 [==============================] - 0s 1ms/step
# step:  43     solution_fitness_child42:  0.6965298204769261
# 38/38 [==============================] - 0s 2ms/step
# step:  44     solution_fitness_child43:  0.6935194804406195
# 38/38 [==============================] - 0s 2ms/step
# step:  45     solution_fitness_child44:  0.6975391136672369
# 38/38 [==============================] - 0s 1ms/step
# step:  46     solution_fitness_child45:  0.6871107657704645
# 38/38 [==============================] - 0s 1ms/step
# step:  47     solution_fitness_child46:  0.6829152836682639
# 38/38 [==============================] - 0s 2ms/step
# step:  48     solution_fitness_child47:  0.6616404554709535
# 38/38 [==============================] - 0s 2ms/step
# step:  49     solution_fitness_child48:  0.6952422177408211
# 38/38 [==============================] - 0s 2ms/step
# step:  50     solution_fitness_child49:  0.632119520569453
# 38/38 [==============================] - 0s 2ms/step
# step:  51     solution_fitness_child50:  0.6246276030363657
# 38/38 [==============================] - 0s 2ms/step
# step:  52     solution_fitness_child51:  0.6710053041200246
# 38/38 [==============================] - 0s 2ms/step
# step:  53     solution_fitness_child52:  0.6509651984230261
# 38/38 [==============================] - 0s 2ms/step
# step:  54     solution_fitness_child53:  0.7024009043330862
# 38/38 [==============================] - 0s 1ms/step
# step:  55     solution_fitness_child54:  0.7099014676718234
# 38/38 [==============================] - 0s 2ms/step
# step:  56     solution_fitness_child55:  0.6990535613166915
# 38/38 [==============================] - 0s 2ms/step
# step:  57     solution_fitness_child56:  0.6903985462000144
# 38/38 [==============================] - 0s 1ms/step
# step:  58     solution_fitness_child57:  0.7077964425044592
# 38/38 [==============================] - 0s 2ms/step
# step:  59     solution_fitness_child58:  0.6865021148879864
# 38/38 [==============================] - 0s 2ms/step
# step:  60     solution_fitness_child59:  0.6607609556138827
# 38/38 [==============================] - 0s 1ms/step
# step:  61     solution_fitness_child60:  0.6621653044108249
# 38/38 [==============================] - 0s 1ms/step
# step:  62     solution_fitness_child61:  0.6979027233018003
# 38/38 [==============================] - 0s 1ms/step
# step:  63     solution_fitness_child62:  0.6985295871266459
# 38/38 [==============================] - 0s 2ms/step
# step:  64     solution_fitness_child63:  0.6154008536438491
# 38/38 [==============================] - 0s 1ms/step
# step:  65     solution_fitness_child64:  0.6449952044156939
# 38/38 [==============================] - 0s 1ms/step
# step:  66     solution_fitness_child65:  0.670120694576976
# 38/38 [==============================] - 0s 1ms/step
# step:  67     solution_fitness_child66:  0.6895576625244124
# 38/38 [==============================] - 0s 2ms/step
# step:  68     solution_fitness_child67:  0.6187079071950625
# 38/38 [==============================] - 0s 2ms/step
# step:  69     solution_fitness_child68:  0.6810576851967811
# 38/38 [==============================] - 0s 2ms/step
# step:  70     solution_fitness_child69:  0.6421203572458817
# 38/38 [==============================] - 0s 2ms/step
# step:  71     solution_fitness_child70:  0.6585555081720171
# 38/38 [==============================] - 0s 1ms/step
# step:  72     solution_fitness_child71:  0.7061086032538764
# 38/38 [==============================] - 0s 2ms/step
# step:  73     solution_fitness_child72:  0.7169676913720462
# 38/38 [==============================] - 0s 1ms/step
# step:  74     solution_fitness_child73:  0.42762493232695953
# 38/38 [==============================] - 0s 1ms/step
# step:  75     solution_fitness_child74:  0.7037624269156462
# 38/38 [==============================] - 0s 1ms/step
# step:  76     solution_fitness_child75:  0.6909962703110172
# 38/38 [==============================] - 0s 1ms/step
# step:  77     solution_fitness_child76:  0.6771979150077296
# 38/38 [==============================] - 0s 2ms/step
# step:  78     solution_fitness_child77:  0.6020854679841677
# 38/38 [==============================] - 0s 2ms/step
# step:  79     solution_fitness_child78:  0.6026172479947471
# 38/38 [==============================] - 0s 1ms/step
# step:  80     solution_fitness_child79:  0.48602273991257794
# 38/38 [==============================] - 0s 1ms/step
# step:  81     solution_fitness_child80:  0.7073777979452807
# 38/38 [==============================] - 0s 2ms/step
# step:  82     solution_fitness_child81:  0.7009708864333
# 38/38 [==============================] - 0s 1ms/step
# step:  83     solution_fitness_child82:  0.541333775280463
# 38/38 [==============================] - 0s 2ms/step
# step:  84     solution_fitness_child83:  0.6869302430001092
# 38/38 [==============================] - 0s 1ms/step
# step:  85     solution_fitness_child84:  0.6508279335790667
# 38/38 [==============================] - 0s 2ms/step
# step:  86     solution_fitness_child85:  0.6751070085117495
# 38/38 [==============================] - 0s 2ms/step
# step:  87     solution_fitness_child86:  0.6971790144885369
# 38/38 [==============================] - 0s 1ms/step
# step:  88     solution_fitness_child87:  0.6851792016367875
# 38/38 [==============================] - 0s 2ms/step
# step:  89     solution_fitness_child88:  0.699129078483687
# 38/38 [==============================] - 0s 1ms/step
# step:  90     solution_fitness_child89:  0.6208960755720094
# 38/38 [==============================] - 0s 3ms/step
# step:  91     solution_fitness_child90:  0.691076530428897
# 38/38 [==============================] - 0s 1ms/step
# step:  92     solution_fitness_child91:  0.6293172863587304
# 38/38 [==============================] - 0s 1ms/step
# step:  93     solution_fitness_child92:  0.6722624054327627
# 38/38 [==============================] - 0s 1ms/step
# step:  94     solution_fitness_child93:  0.6912963008518177
# 38/38 [==============================] - 0s 1ms/step
# step:  95     solution_fitness_child94:  0.6534389939929447
# 38/38 [==============================] - 0s 1ms/step
# step:  96     solution_fitness_child95:  0.7119203532952029
# 38/38 [==============================] - 0s 1ms/step
# step:  97     solution_fitness_child96:  0.7023312651410365
# 38/38 [==============================] - 0s 1ms/step
# step:  98     solution_fitness_child97:  0.6612570831173046
# 38/38 [==============================] - 0s 1ms/step
# step:  99     solution_fitness_child98:  0.6474159446030625
# 38/38 [==============================] - 0s 1ms/step
# step:  100     solution_fitness_child99:  0.6295084030079438
# 38/38 [==============================] - 0s 2ms/step
# step:  101     solution_fitness_child100:  0.6930801858908242
# 38/38 [==============================] - 0s 1ms/step
# step:  102     solution_fitness_child101:  0.7099995312027794
# 38/38 [==============================] - 0s 2ms/step
# step:  103     solution_fitness_child102:  0.6433274422659814
# 38/38 [==============================] - 0s 2ms/step
# step:  104     solution_fitness_child103:  0.7261895089619782
# 38/38 [==============================] - 0s 2ms/step
# step:  105     solution_fitness_child104:  0.6869359946435292
# 38/38 [==============================] - 0s 1ms/step
# step:  106     solution_fitness_child105:  0.6932605362852282
# 38/38 [==============================] - 0s 2ms/step
# step:  107     solution_fitness_child106:  0.6881953860850321
# 38/38 [==============================] - 0s 2ms/step
# step:  108     solution_fitness_child107:  0.6380791404673545
# 38/38 [==============================] - 0s 1ms/step
# step:  109     solution_fitness_child108:  0.7061262557313761
# 38/38 [==============================] - 0s 2ms/step
# step:  110     solution_fitness_child109:  0.7000130893711742
# 38/38 [==============================] - 0s 2ms/step
# step:  111     solution_fitness_child110:  0.6704134424994757
# 38/38 [==============================] - 0s 2ms/step
# step:  112     solution_fitness_child111:  0.7014759665781503
# 38/38 [==============================] - 0s 1ms/step
# step:  113     solution_fitness_child112:  0.6965093502602209
# 38/38 [==============================] - 0s 2ms/step
# step:  114     solution_fitness_child113:  0.6951286889314119
# 38/38 [==============================] - 0s 2ms/step
# step:  115     solution_fitness_child114:  0.6339172961228244
# 38/38 [==============================] - 0s 2ms/step
# step:  116     solution_fitness_child115:  0.6964806532087868
# 38/38 [==============================] - 0s 2ms/step
# step:  117     solution_fitness_child116:  0.6881957911492169
# 38/38 [==============================] - 0s 1ms/step
# step:  118     solution_fitness_child117:  0.6764090917897032
# 38/38 [==============================] - 0s 2ms/step
# step:  119     solution_fitness_child118:  0.6747772752349734
# 38/38 [==============================] - 0s 1ms/step
# step:  120     solution_fitness_child119:  0.6847519571507088
# 38/38 [==============================] - 0s 2ms/step
# step:  121     solution_fitness_child120:  0.6975670669907972
# 38/38 [==============================] - 0s 1ms/step
# step:  122     solution_fitness_child121:  0.5785525638983959
# 38/38 [==============================] - 0s 1ms/step
# step:  123     solution_fitness_child122:  0.693503446222296
# 38/38 [==============================] - 0s 2ms/step
# step:  124     solution_fitness_child123:  0.7045928145337232
# 38/38 [==============================] - 0s 1ms/step
# step:  125     solution_fitness_child124:  0.6872490043571499

# %%
best_slutions
# Out:
#     nurn1 nurn2 nurn3 nurn4 Active1 Active2 Active3 Active4 Drop1 Drop2 Drop3  \
# 61     97   137    76    12      12       5       9       9     0     1     0
# 112    97   137    76    12      12       5       9       9     0     1     0
# 123   135    25   149    82       3      14       2       3     1     1     0
# 124    68    60   149    78      10       9      14       2     1     0     0
# 124    64    19   149    91       1       7      13       4     0     1     1
# 124    53    94   137    82      12       7       1       0     1     0     0
#
#     Drop4 Norm1 Norm2 Norm3 Norm4  Learn_rate batch_size solution_fitness
# 61      0     0     1     0     1       0.010        220         0.727417
# 112     0     0     1     0     1       0.010        220         0.724919
# 123     1     0     1     1     0       0.010        135         0.731489
# 124     0     0     1     1     1       0.010        205         0.710515
# 124     0     0     1     0     0       0.010        205         0.717048
# 124     0     1     1     1     1       0.001         50          0.72619
